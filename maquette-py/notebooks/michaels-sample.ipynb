# %%
import maquette as mq
import pandas as pd

# %%
mq.datasets()
# Out:
# b'[ {\n  "id" : "b8cec40a",\n  "title" : "Fraudulent Transactions",\n  "name" : "fraud-analysis",\n  "summary" : "Fraudulent banking transactions of a Spanish bank",\n  "visibility" : "public",\n  "classification" : "internal",\n  "personalInformation" : "pi",\n  "created" : {\n    "by" : "alice",\n    "at" : "2021-01-26T18:57:33.334149Z"\n  },\n  "updated" : {\n    "by" : "alice",\n    "at" : "2021-01-26T18:57:33.334149Z"\n  }\n}, {\n  "id" : "36686b6d",\n  "title" : "City Temperatures",\n  "name" : "city-temperature",\n  "summary" : "Historical weather data of major cities of Europe",\n  "visibility" : "public",\n  "classification" : "public",\n  "personalInformation" : "none",\n  "created" : {\n    "by" : "alice",\n    "at" : "2021-01-26T18:57:04.925545Z"\n  },\n  "updated" : {\n    "by" : "alice",\n    "at" : "2021-01-26T18:57:04.925545Z"\n  }\n} ]'

# %%
mq.dataset('city-temperature').get()
# Out:
#         Region     Country  State      City  Month  Day  Year  AvgTemperature
# 0       Europe     Albania    NaN    Tirana      1    1  1995           -99.0
# 1       Europe     Albania    NaN    Tirana      1    2  1995           -99.0
# 2       Europe     Albania    NaN    Tirana      1    3  1995           -99.0
# 3       Europe     Albania    NaN    Tirana      1    4  1995           -99.0
# 4       Europe     Albania    NaN    Tirana      1    5  1995           -99.0
# ...        ...         ...    ...       ...    ...  ...   ...             ...
# 381985  Europe  Yugoslavia    NaN  Belgrade      5    9  2020            66.2
# 381986  Europe  Yugoslavia    NaN  Belgrade      5   10  2020            70.7
# 381987  Europe  Yugoslavia    NaN  Belgrade      5   11  2020            72.5
# 381988  Europe  Yugoslavia    NaN  Belgrade      5   12  2020            61.5
# 381989  Europe  Yugoslavia    NaN  Belgrade      5   13  2020            51.8
#
# [381990 rows x 8 columns]

# %%
def import_excel(file, dataset, title, summary, classification='public'):
    mq.Dataset(dataset, title=title, summary=summary).create()
    df = pd.read_excel('/Users/michaelwellner/Downloads/b2b.xlsx', engine='openpyxl', nrows=1000, keep_default_na=False)
    df.columns = map(lambda s: ''.join(x for x in s.lower() if x.isalnum()), df.columns)
    mq.dataset(dataset).put(df, "Exported from D&B")

# %%
#import_excel('/Users/michaelwellner/Downloads/b2b.xlsx', 'db-bb', 'D&B B&B', 'Lorem Ipsum dolor')
#import_excel('/Users/michaelwellner/Downloads/b2b-zb.xlsx', 'db-b2b-zb', 'D&B B&B ZB', 'Lorem Ipsum dolor')
import_excel('/Users/michaelwellner/Downloads/b2b-bc.xlsx', 'db-b2c', 'D&B B&C', 'Lorem Ipsum dolor')

# %%
df = pd.read_excel('/Users/michaelwellner/Downloads/b2b.xlsx', engine='openpyxl', nrows=1000, keep_default_na=False)

# %%
mq.Dataset("test").create()

# %%
df.columns = map(lambda s: ''.join(x for x in s.lower() if x.isalnum()), df.columns)
df
# Out:
#           duns handelsregisternummer              uid  \
# 0    480190258         CH02030448602  CHE-342.404.132
# 1    480255743
# 2    480141388                        CHE-156.749.458
# 3    483753385
# 4    480224984         CH02039179029  CHE-102.547.095
# ..         ...                   ...              ...
# 995  480242280         CH50110195125  CHE-497.974.362
# 996  485677889         CH32040676780  CHE-115.898.888
# 997  485713846
# 998  483905738
# 999  480380444         CH02040662407  CHE-467.521.926
#
#                                       firma    handelsname codomiziladresse  \
# 0                                  KEEAS AG
# 1                          Morena Rüfenacht  morena isabel
# 2                           massage-for-you
# 3                           Schulverwaltung
# 4    Monterey Immobilien und Verwaltungs AG
# ..                                      ...            ...              ...
# 995        Ampersand Labs by Davide Morotti
# 996                              CforC GmbH
# 997                             Ulrich Frei
# 998  Biblische Seelsorge und Lebensberatung
# 999                         Yourdriver GmbH
#
#              domiziladresse zusatzdomiziladresse  plzdomiziladresse  \
# 0            Sihlstrasse 59                                    8001
# 1        Kreuzbühlstrasse 8                                    8008
# 2        Auwiesenstrasse 55                                    8406
# 3    Breiteackerstrasse 46b                                    8422
# 4            Dorfstrasse 51                                    8712
# ..                      ...                  ...                ...
# 995          Kreuzstrasse 2                                    8008
# 996   Buchgrindelstrasse 13                                    8621
# 997          Obere Zäune 24                                    8001
# 998              Zeltweg 47                                    8610
# 999        Im Amtsacker 12a                                    8424
#
#     ortdomiziladresse  ...                                     rating  \
# 0              Zürich  ...  Einbezahltes Kapital CHF 90'000 - 179'999
# 1              Zürich  ...     Die finanziellen Mittel sind unbekannt
# 2          Winterthur  ...     Die finanziellen Mittel sind unbekannt
# 3             Pfungen  ...     Eigenkapital CHF 1'800'000 - 3'499'999
# 4               Stäfa  ...  Einbezahltes Kapital CHF 90'000 - 179'999
# ..                ...  ...                                        ...
# 995            Zürich  ...     Die finanziellen Mittel sind unbekannt
# 996       Wetzikon ZH  ...   Einbezahltes Kapital CHF 20'000 - 49'999
# 997            Zürich  ...     Die finanziellen Mittel sind unbekannt
# 998             Uster  ...     Die finanziellen Mittel sind unbekannt
# 999           Embrach  ...   Einbezahltes Kapital CHF 20'000 - 49'999
#
#                                     ratingtext            risikoindikatortext  \
# 0    Einbezahltes Kapital CHF 90'000 - 179'999  geringes bis mittleres Risiko
# 1       Die finanziellen Mittel sind unbekannt   mittleres bis höheres Risiko
# 2       Die finanziellen Mittel sind unbekannt  geringes bis mittleres Risiko
# 3       Eigenkapital CHF 1'800'000 - 3'499'999  kein bis sehr geringes Risiko
# 4    Einbezahltes Kapital CHF 90'000 - 179'999  kein bis sehr geringes Risiko
# ..                                         ...                            ...
# 995     Die finanziellen Mittel sind unbekannt  geringes bis mittleres Risiko
# 996   Einbezahltes Kapital CHF 20'000 - 49'999  geringes bis mittleres Risiko
# 997     Die finanziellen Mittel sind unbekannt   mittleres bis höheres Risiko
# 998     Die finanziellen Mittel sind unbekannt
# 999   Einbezahltes Kapital CHF 20'000 - 49'999   mittleres bis höheres Risiko
#
#     score höchstkredit  aktivitätsstatus  wirtschaftlicheaktivität  \
# 0      73        20000             aktiv  Ist wirtschaftlich aktiv
# 1      31         5000             aktiv
# 2      57         5000             aktiv
# 3     100       100000             aktiv  Ist wirtschaftlich aktiv
# 4      99        20000             aktiv  Ist wirtschaftlich aktiv
# ..    ...          ...               ...                       ...
# 995    81         5000             aktiv  Ist wirtschaftlich aktiv
# 996    68        15000             aktiv
# 997    37        10000             aktiv
# 998                                aktiv  Ist wirtschaftlich aktiv
# 999    33         5000             aktiv
#
#     anzahlrechnungenduntrade totalbetragrechnungenduntrade paydex
# 0                          7                       1500.00     80
# 1
# 2
# 3                          4                        450.00
# 4                          3                       1400.00
# ..                       ...                           ...    ...
# 995                        2                        200.00
# 996
# 997
# 998                        1                        200.00
# 999
#
# [1000 rows x 155 columns]

# %%
mq.dataset("test").put(df, "test")
# Out:
# '1.0.0'
